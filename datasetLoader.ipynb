# %%
# !pip install tensorflow
# !pip install spektral
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple/
# Requirement already satisfied: tensorflow in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (2.8.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from tensorflow) (0.24.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/liyang/.local/lib/python3.8/site-packages (from tensorflow) (3.10.0.2)
# Requirement already satisfied: numpy>=1.20 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from tensorflow) (1.21.2)
# Requirement already satisfied: wrapt>=1.11.0 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from tensorflow) (1.13.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from tensorflow) (1.43.0)
# Requirement already satisfied: protobuf>=3.9.2 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from tensorflow) (3.19.4)
# Requirement already satisfied: flatbuffers>=1.12 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from tensorflow) (2.0)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from tensorflow) (2.8.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: six>=1.12.0 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: gast>=0.2.1 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: absl-py>=0.4.0 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from tensorflow) (1.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: tf-estimator-nightly==2.8.0.dev2021122109 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from tensorflow) (2.8.0.dev2021122109)
# Requirement already satisfied: h5py>=2.9.0 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from tensorflow) (3.6.0)
# Requirement already satisfied: libclang>=9.0.1 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from tensorflow) (13.0.0)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from tensorflow) (2.8.0)
# Requirement already satisfied: setuptools in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from tensorflow) (58.4.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from astunparse>=1.6.0->tensorflow) (0.37.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from tensorboard<2.9,>=2.8->tensorflow) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from tensorboard<2.9,>=2.8->tensorflow) (3.3.6)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from tensorboard<2.9,>=2.8->tensorflow) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from tensorboard<2.9,>=2.8->tensorflow) (2.6.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from tensorboard<2.9,>=2.8->tensorflow) (2.26.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from tensorboard<2.9,>=2.8->tensorflow) (1.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from tensorboard<2.9,>=2.8->tensorflow) (2.0.3)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (5.0.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow) (4.11.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (2.0.6)
# Requirement already satisfied: idna<4,>=2.5 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (2021.10.8)
# Requirement already satisfied: zipp>=0.5 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow) (3.7.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow) (3.2.0)
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple/
# Collecting spektral
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/26/63/d756a1490d360d1cb398bb606eb282054e702e213ea983d3f76e99b83334/spektral-1.0.8-py3-none-any.whl (123 kB)
#      |████████████████████████████████| 123 kB 1.6 MB/s
# Requirement already satisfied: scikit-learn in /home/liyang/.local/lib/python3.8/site-packages (from spektral) (0.24.2)
# Requirement already satisfied: networkx in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from spektral) (2.6.3)
# Requirement already satisfied: tensorflow>=2.1.0 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from spektral) (2.8.0)
# Collecting numpy<1.20
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/66/d7/3b133b17e185f14137bc8afe7a41daf1f31556900f10238312a5ae9c7345/numpy-1.19.5-cp38-cp38-manylinux2010_x86_64.whl (14.9 MB)
#      |████████████████████████████████| 14.9 MB 1.9 MB/s
# Requirement already satisfied: pandas in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from spektral) (1.3.4)
# Requirement already satisfied: joblib in /home/liyang/.local/lib/python3.8/site-packages (from spektral) (1.0.1)
# Collecting lxml
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/ae/64/f002c327e99a3f3e8ec5c84590f665c071a39f85547987bdbab585fda1df/lxml-4.7.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (6.9 MB)
#      |████████████████████████████████| 6.9 MB 2.9 MB/s
# Requirement already satisfied: requests in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from spektral) (2.26.0)
# Requirement already satisfied: tqdm in /home/liyang/.local/lib/python3.8/site-packages (from spektral) (4.62.2)
# Requirement already satisfied: scipy in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from spektral) (1.7.1)
# Requirement already satisfied: libclang>=9.0.1 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from tensorflow>=2.1.0->spektral) (13.0.0)
# Requirement already satisfied: flatbuffers>=1.12 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from tensorflow>=2.1.0->spektral) (2.0)
# Requirement already satisfied: h5py>=2.9.0 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from tensorflow>=2.1.0->spektral) (3.6.0)
# Requirement already satisfied: six>=1.12.0 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from tensorflow>=2.1.0->spektral) (1.16.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from tensorflow>=2.1.0->spektral) (0.2.0)
# Requirement already satisfied: protobuf>=3.9.2 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from tensorflow>=2.1.0->spektral) (3.19.4)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from tensorflow>=2.1.0->spektral) (2.8.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from tensorflow>=2.1.0->spektral) (1.13.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from tensorflow>=2.1.0->spektral) (3.3.0)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from tensorflow>=2.1.0->spektral) (2.8.0)
# Requirement already satisfied: setuptools in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from tensorflow>=2.1.0->spektral) (58.4.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from tensorflow>=2.1.0->spektral) (1.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from tensorflow>=2.1.0->spektral) (1.6.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from tensorflow>=2.1.0->spektral) (1.43.0)
# Requirement already satisfied: absl-py>=0.4.0 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from tensorflow>=2.1.0->spektral) (1.0.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/liyang/.local/lib/python3.8/site-packages (from tensorflow>=2.1.0->spektral) (3.10.0.2)
# Requirement already satisfied: gast>=0.2.1 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from tensorflow>=2.1.0->spektral) (0.5.3)
# Collecting tensorflow>=2.1.0
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/95/7b/7454dc83f4cabb3e051f8338e7a521a190981b9e9f8b29fcf944f2aa035f/tensorflow-2.7.1-cp38-cp38-manylinux2010_x86_64.whl (495.1 MB)
#      |████████████████████████████████| 495.1 MB 4.7 kB/s
# Collecting keras<2.8,>=2.7.0rc0
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/6b/8b/065f94ba03282fa41b2d76942b87a180a9913312c4611ea7d6508fbbc114/keras-2.7.0-py2.py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 1.7 MB/s
# Requirement already satisfied: wheel<1.0,>=0.32.0 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from tensorflow>=2.1.0->spektral) (0.37.0)
# Collecting gast<0.5.0,>=0.2.1
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/b6/48/583c032b79ae5b3daa02225a675aeb673e58d2cb698e78510feceb11958c/gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting tensorflow-estimator<2.8,~=2.7.0rc0
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/db/de/3a71ad41b87f9dd424e3aec3b0794a60f169fa7e9a9a1e3dd44290b86dd6/tensorflow_estimator-2.7.0-py2.py3-none-any.whl (463 kB)
#      |████████████████████████████████| 463 kB 2.5 MB/s
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from tensorflow>=2.1.0->spektral) (1.1.2)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.21.0 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from tensorflow>=2.1.0->spektral) (0.24.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/liyang/.local/lib/python3.8/site-packages (from pandas->spektral) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /home/liyang/.local/lib/python3.8/site-packages (from pandas->spektral) (2021.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from requests->spektral) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from requests->spektral) (2.0.6)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from requests->spektral) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from requests->spektral) (2021.10.8)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/liyang/.local/lib/python3.8/site-packages (from scikit-learn->spektral) (2.2.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.1.0->spektral) (2.6.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.1.0->spektral) (1.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.1.0->spektral) (2.0.3)
# Requirement already satisfied: markdown>=2.6.8 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.1.0->spektral) (3.3.6)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.1.0->spektral) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.1.0->spektral) (0.6.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.1.0->spektral) (4.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.1.0->spektral) (5.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.1.0->spektral) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow>=2.1.0->spektral) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow>=2.1.0->spektral) (4.11.1)
# Requirement already satisfied: zipp>=0.5 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow>=2.1.0->spektral) (3.7.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.1.0->spektral) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/liyang/anaconda3/envs/xgraph/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow>=2.1.0->spektral) (3.2.0)
# Installing collected packages: numpy, tensorflow-estimator, keras, gast, tensorflow, lxml, spektral
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.2
#     Uninstalling numpy-1.21.2:
#       Successfully uninstalled numpy-1.21.2
#   Attempting uninstall: keras
#     Found existing installation: keras 2.8.0
#     Uninstalling keras-2.8.0:
#       Successfully uninstalled keras-2.8.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.5.3
#     Uninstalling gast-0.5.3:
#       Successfully uninstalled gast-0.5.3
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.8.0
#     Uninstalling tensorflow-2.8.0:
#       Successfully uninstalled tensorflow-2.8.0
# Successfully installed gast-0.4.0 keras-2.7.0 lxml-4.7.1 numpy-1.19.5 spektral-1.0.8 tensorflow-2.7.1 tensorflow-estimator-2.7.0

# %%
import os
import numpy as np

from joblib import Parallel, delayed
from tensorflow.keras.utils import get_file
from tqdm import tqdm

from spektral.data import Dataset, Graph
from spektral.utils import label_to_one_hot, sparse
from spektral.utils.io import load_csv, load_sdf

ATOM_TYPES = [1, 6, 7, 8, 9]
BOND_TYPES = [1, 2, 3, 4]

class QM9(Dataset):

    ## This class is modified from Spektral to read sdf file in local enviornment

    url = "https://deepchemdata.s3-us-west-1.amazonaws.com/datasets/gdb9.tar.gz"

    def __init__(self, amount = None, n_jobs = 1, **kwargs):
        self.amount = amount
        self.n_jobs = n_jobs
        super().__init__(**kwargs)

    def download(self):
        get_file(
            "qm9.tar.gz",
            self.url,
            extract = True,
            cache_dir = self.path,
            cache_subdir = self.path,
        )
        os.remove(os.path.join(self.path, "qm9.tar.gz"))

    def read(self):
        print("loading QM9 dataset.")
        #load  dir and file_name
        sdf_file = os.path.join("/home/liyang/Documents/csprogram/graph-mol-infer-main/sdf_files", "gdb9_15794_eli.sdf")
        data = load_sdf(sdf_file, amount = self.amount)

        def read_mol(mol):
            x = np.array([atom_to_feature(atom) for atom in mol["atoms"]])
            a, e = mol_to_adj(mol)
            return x, a ,e

        data = Parallel(n_jobs=self.n_jobs)(
            delayed(read_mol)(mol) for mol in tqdm(data, ncols=80)
        )
        x_list, a_list, e_list = list(zip(*data))

        #load labels
        labels_file = os.path.join(self.path, "gdb9.sdf.csv")
        labels = load_csv(labels_file)
        labels = labels.set_index("mol_id").values
        if self.amount is not None:
            labels = labels[:self.amount]

        return [
            Graph(x=x, a=a, e=e, y=y)
            for x, a, e, y in zip(x_list, a_list, e_list, labels)
        ]


def atom_to_feature(atom):
    atomic_num = label_to_one_hot(atom["atomic_num"], ATOM_TYPES)
    coords = atom["coords"]
    charge = atom["charge"]
    iso = atom["iso"]

    return np.concatenate((atomic_num, coords, [charge, iso]), -1)

def mol_to_adj(mol):
    row, col, edge_features = [], [], []
    for bond in mol["bonds"]:
        start, end = bond["start_atom"], bond["end_atom"]
        row += [start, end]
        col += [end, start]
        edge_features += [bond["type"]] * 2

    a, e = sparse.edge_index_to_matrix(
        edge_index=np.array((row, col)).T,
        edge_weight=np.ones_like(row),
        edge_features=label_to_one_hot(edge_features, BOND_TYPES),
    )

    return a, e

# %%
dataset = QM9()
print(dataset)
print(dataset[0])
# Out:
# loading QM9 dataset.
# Reading SDF
# 100%|████████████████████████████████████| 15794/15794 [00:22<00:00, 701.69it/s]
# QM9(n_graphs=15794)
# Graph(n_nodes=14, n_node_features=10, n_edge_features=4, n_labels=19)
